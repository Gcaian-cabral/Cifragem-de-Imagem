# %%
# !pip install pillow
import PIL

# %%
import numpy as np
from PIL import Image

# %%
im1 = Image.open("im1.png")
im2 = Image.open("im2.png")

# %%
im1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=813x602 at 0x7FB3E475BA30>

# %%
im2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=432x422 at 0x7FB3E475BE50>

# %%
bw_im1 = im1.convert('1') 
bw_im2 = im2.convert('1')

# %%
result = ImageChops.logical_xor(bw_im2,bw_im1)

# %%
result.save('Imagens_Resultado/result.png')

# %%
result2 = ImageChops.logical_xor(result, bw_im2)

# %%
result2.save('Imagens_Resultado/result2.png')
